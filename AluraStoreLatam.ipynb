# %% [markdown]
# <a href="https://colab.research.google.com/github/ceroyunohub/challenge1-data-science/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# Calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
ingreso_total_tienda1 = tienda['Precio'].sum()
ingreso_total_tienda2 = tienda2['Precio'].sum()
ingreso_total_tienda3 = tienda3['Precio'].sum()
ingreso_total_tienda4 = tienda4['Precio'].sum()

print(f"Ingreso total Tienda 1: {ingreso_total_tienda1:,.2f}")
print(f"Ingreso total Tienda 2: {ingreso_total_tienda2:,.2f}")
print(f"Ingreso total Tienda 3: {ingreso_total_tienda3:,.2f}")
print(f"Ingreso total Tienda 4: {ingreso_total_tienda4:,.2f}")
# Out:
# Ingreso total Tienda 1: 1,150,880,400.00
# Ingreso total Tienda 2: 1,116,343,500.00
# Ingreso total Tienda 3: 1,098,019,600.00
# Ingreso total Tienda 4: 1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
#  Calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.
#
#  **Se cosidero como más populares a las primeras 5 categorias de mayor cantidad.**

# %%
ventas_por_categoria_tienda1 = tienda.groupby('Categoría del Producto').size().sort_values(ascending=False)
ventas_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto').size().sort_values(ascending=False)
ventas_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto').size().sort_values(ascending=False)
ventas_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto').size().sort_values(ascending=False)

print("\nVentas por Categoría - Tienda 1:")
print(ventas_por_categoria_tienda1.head().to_string())

print("\nVentas por Categoría - Tienda 2:")
print(ventas_por_categoria_tienda2.head().to_string())

print("\nVentas por Categoría - Tienda 3:")
print(ventas_por_categoria_tienda3.head().to_string())

print("\nVentas por Categoría - Tienda 4:")
print(ventas_por_categoria_tienda4.head().to_string())
# Out:
# Ventas por Categoría - Tienda 1:
# Categoría del Producto
# Muebles                 465
# Electrónicos            448
# Juguetes                324
# Electrodomésticos       312
# Deportes y diversión    284
#
# Ventas por Categoría - Tienda 2:
# Categoría del Producto
# Muebles                 442
# Electrónicos            422
# Juguetes                313
# Electrodomésticos       305
# Deportes y diversión    275
#
# Ventas por Categoría - Tienda 3:
# Categoría del Producto
# Muebles                 499
# Electrónicos            451
# Juguetes                315
# Electrodomésticos       278
# Deportes y diversión    277
#
# Ventas por Categoría - Tienda 4:
# Categoría del Producto
# Muebles                 480
# Electrónicos            451
# Juguetes                338
# Deportes y diversión    277
# Electrodomésticos       254

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# Calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calificacion_promedio_tienda1 = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

print(f"Calificación promedio Tienda 1: {calificacion_promedio_tienda1:.2f}")
print(f"Calificación promedio Tienda 2: {calificacion_promedio_tienda2:.2f}")
print(f"Calificación promedio Tienda 3: {calificacion_promedio_tienda3:.2f}")
print(f"Calificación promedio Tienda 4: {calificacion_promedio_tienda4:.2f}")
# Out:
# Calificación promedio Tienda 1: 3.98
# Calificación promedio Tienda 2: 4.04
# Calificación promedio Tienda 3: 4.05
# Calificación promedio Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# Identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualizar los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
mas_vendidos_tienda1 = tienda['Producto'].value_counts()
mas_vendidos_tienda2 = tienda2['Producto'].value_counts()
mas_vendidos_tienda3 = tienda3['Producto'].value_counts()
mas_vendidos_tienda4 = tienda4['Producto'].value_counts()

print("Productos más vendidos - Tienda 1:")
print(mas_vendidos_tienda1.head().to_string())

print("\nProductos más vendidos - Tienda 2:")
print(mas_vendidos_tienda2.head().to_string())

print("\nProductos más vendidos - Tienda 3:")
print(mas_vendidos_tienda3.head().to_string())

print("\nProductos más vendidos - Tienda 4:")
print(mas_vendidos_tienda4.head().to_string())
# Out:
# Productos más vendidos - Tienda 1:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
#
# Productos más vendidos - Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
#
# Productos más vendidos - Tienda 3:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
#
# Productos más vendidos - Tienda 4:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55

# %%
menos_vendidos_tienda1 = tienda['Producto'].value_counts(ascending=True)
menos_vendidos_tienda2 = tienda2['Producto'].value_counts(ascending=True)
menos_vendidos_tienda3 = tienda3['Producto'].value_counts(ascending=True)
menos_vendidos_tienda4 = tienda4['Producto'].value_counts(ascending=True)

print("\nProductos menos vendidos - Tienda 1:")
print(menos_vendidos_tienda1.head().to_string())

print("\nProductos menos vendidos - Tienda 2:")
print(menos_vendidos_tienda2.head().to_string())

print("\nProductos menos vendidos - Tienda 3:")
print(menos_vendidos_tienda3.head().to_string())

print("\nProductos menos vendidos - Tienda 4:")
print(menos_vendidos_tienda4.head().to_string())
# Out:
# Productos menos vendidos - Tienda 1:
# Producto
# Auriculares con micrófono    33
# Celular ABXY                 33
# Olla de presión              35
# Pandereta                    36
# Mochila                      39
#
# Productos menos vendidos - Tienda 2:
# Producto
# Juego de mesa      32
# Mesa de comedor    34
# Impresora          34
# Sillón             35
# Auriculares        37
#
# Productos menos vendidos - Tienda 3:
# Producto
# Bloques de construcción    35
# Set de vasos               36
# Microondas                 36
# Mochila                    36
# Guitarra eléctrica         38
#
# Productos menos vendidos - Tienda 4:
# Producto
# Guitarra eléctrica    33
# Armario               34
# Guitarra acústica     37
# Refrigerador          38
# Lavadora de ropa      38

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# Calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %%
costo_envio_promedio_tienda1 = tienda['Costo de envío'].mean()
costo_envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

print(f"Costo de envío promedio Tienda 1: {costo_envio_promedio_tienda1:.2f}")
print(f"Costo de envío promedio Tienda 2: {costo_envio_promedio_tienda2:.2f}")
print(f"Costo de envío promedio Tienda 3: {costo_envio_promedio_tienda3:.2f}")
print(f"Costo de envío promedio Tienda 4: {costo_envio_promedio_tienda4:.2f}")
# Out:
# Costo de envío promedio Tienda 1: 26018.61
# Costo de envío promedio Tienda 2: 25216.24
# Costo de envío promedio Tienda 3: 24805.68
# Costo de envío promedio Tienda 4: 23459.46

# %% [markdown]
# # 6. Visualización

# %% [markdown]
# Generar al menos tres gráficos. Estos gráficos deben ser de diferentes tipos (como barras, líneas, dispersión, entre otros) para presentar una visión completa de los datos.
#
# Los gráficos deben complementar el análisis realizado, resaltando los puntos más relevantes, como los ingresos de la tienda, la distribución de categorías de productos, las opiniones de los clientes, los productos más vendidos y/o los costes de envío.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for Plot 1: Total Revenue per Store (Bar Chart)
revenues = {
    'Tienda 1': ingreso_total_tienda1,
    'Tienda 2': ingreso_total_tienda2,
    'Tienda 3': ingreso_total_tienda3,
    'Tienda 4': ingreso_total_tienda4
}

stores = list(revenues.keys())
total_revenues = list(revenues.values())

plt.figure(figsize=(10, 6))
plt.bar(stores, total_revenues, color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
plt.xlabel('Tienda')
plt.ylabel('Ingreso Total (COP)')
plt.title('Ingreso Total por Tienda')
plt.ticklabel_format(style='plain', axis='y') # Evitar notación científica en el eje Y
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Distribución de las principales categorías de productos de la Tienda

top_n = 5 # categorias principales
other_category_name = 'Otros'


top_categories = ventas_por_categoria_tienda1.head(top_n)


pie_data = pd.concat([top_categories, pd.Series({other_category_name: other_categories_sum})])

plt.figure(figsize=(10, 8))
plt.pie(pie_data, labels=pie_data.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title(f'Distribución de las Categorías de Productos en Tienda 1 (Top {top_n} + Otros)')
plt.axis('equal')
plt.show()

# %%
# Calificación Promedio de Clientes por Tienda
average_ratings = {
    'Tienda 1': calificacion_promedio_tienda1,
    'Tienda 2': calificacion_promedio_tienda2,
    'Tienda 3': calificacion_promedio_tienda3,
    'Tienda 4': calificacion_promedio_tienda4
}

stores_ratings = list(average_ratings.keys())
ratings_values = list(average_ratings.values())

plt.figure(figsize=(10, 6))
plt.plot(stores_ratings, ratings_values, marker='o', linestyle='-', color='blue')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.title('Calificación Promedio de Clientes por Tienda')
plt.ylim(0, 5) # Escala de 1-5
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # 7. Informe final

# %% [markdown]
# **Introducción**
#
# El propósito de este análisis es determinar en qué tienda debería vender el Sr. Juan, considerando múltiples factores clave: ingresos totales, categorías de productos más y menos vendidas, calificaciones promedio de clientes, productos destacados en ventas y coste de envío promedio. El objetivo es identificar la tienda que ofrece mejores condiciones de rentabilidad, satisfacción del cliente y competitividad logística, respaldando la decisión con datos y visualizaciones.</br>
# </br>
#
#
# ---
#
#
# **Desarrollo del análisis**
# </br></br>
# 1. Ingresos totales
#
# * Tienda 1: 1,150,880,400
#
# * Tienda 2: 1,116,343,500
#
# * Tienda 3: 1,098,019,600
#
# * Tienda 4: 1,038,375,700
# </br>
# La Tienda 1 lidera en ingresos, lo que refleja mayor volumen de ventas y potencial de mercado.</br></br>
#
#
# 2. Categorías más vendidas
#
# * Todas las tiendas muestran Muebles y Electrónicos como las categorías más populares.
#
# * En menor medida destacan Juguetes y Electrodomésticos.
#
# * Esto indica un patrón de consumo estable y diversificado, con fuerte demanda en bienes duraderos.</br></br>
#
# 3. Calificaciones promedio de clientes
#
# * Tienda 1: 3.98
#
# * Tienda 2: 4.04
#
# * Tienda 3: 4.05
#
# * Tienda 4: 4.00
# </br>
# La Tienda 3 obtiene la mejor calificación promedio, lo que refleja mayor satisfacción de los clientes.</br></br>
#
# 4. Productos más vendidos
#
# * Tienda 1: Microondas, TV LED UHD 4K, Armario.
#
# * Tienda 2: Curso “Iniciando en programación”, Microondas, Batería.
#
# * Tienda 3: Kit de bancas, Mesa de comedor, Cama king.
#
# * Tienda 4: Cama box, Cubertería, Carrito de control remoto.
#
# * La Tienda 1 y la Tienda 3 destacan por productos de alta rotación y valor.</br></br>
#
#
# 5. Productos menos vendidos
#
# * Tienda 1: Auriculares con micrófono, Celular ABXY.
#
# * Tienda 2: Juegos de mesa, Impresoras.
#
# * Tienda 3: Bloques de construcción, Microondas.
#
# * Tienda 4: Guitarras eléctricas, Lavadoras.</br></br>
#
# La baja rotación en ciertos productos refleja nichos poco atractivos, pero no compromete las categorías principales.</br></br>
#
# 6. Coste de envío promedio
#
# * Tienda 1: 26,018.61
#
# * Tienda 2: 25,216.24
#
# * Tienda 3: 24,805.68
#
# * Tienda 4: 23,459.46
#
#
# </br></br>La Tienda 4 tiene el menor coste de envío, lo que representa una ventaja logística, aunque sus ingresos son los más bajos.</br></br>
#
#
#
# ---
#
#
# Visualizaciones destacadas</br></br>
#
# Gráfico de barras: Ingresos totales por tienda → Tienda 1 sobresale.![image.png](data:image/png;base64,...)
#
#
#
# Gráfico circular: Distribución de categorías → Muebles y Electrónicos dominan.
# ![image.png](data:image/png;base64,...)
#
# Gráfico de líneas: Calificaciones promedio → Tienda 3 lidera en satisfacción.
#
#
# ![image.png](data:image/png;base64,...)
#
# **Conclusión y recomendación**
#
# <br><br>
# Tras evaluar todos los factores, se recomienda que el Sr. Juan venda en la Tienda 1.
# <br><br>
#
# Justificación:
#
# * Es la tienda con mayores ingresos totales, lo que asegura un mercado amplio y dinámico.
#
# * Sus categorías más vendidas (Muebles y Electrónicos) son consistentes con la demanda general.
#
# * Aunque su calificación promedio es ligeramente inferior a la Tienda 3, sigue siendo aceptable y competitiva.
#
# * Los productos más vendidos son de alto valor y rotación, lo que aumenta la probabilidad de éxito comercial.
#
# * El coste de envío es más alto que en otras tiendas, pero se compensa con el volumen de ventas y la rentabilidad.
#
#
# ---
#
# **En resumen, la Tienda 1 combina el mayor potencial de ingresos con una base de clientes sólida y productos de alta demanda, lo que la convierte en la mejor opción estratégica para el Sr. Juan.**
